# %%
while 1:
    print("1. Enter new student information")
    print("2. Exit")
    print("\n")
    choice = int(input("Enter your choice here: "))
    if choice == 1:
        print("You have chose to calculate the grade for student.")
        
        #For exams ........
        no_of_ex = int(input("How many ex were given? "))
        ex_grade_list = []
        total = 0
        for i in range(0, no_of_exams):    
            ex_grade = int(input("Enter ex grade: "))
            while (exam_grade not in range(0, 100)):
                print("Invalid grade. Must be between 0 and 100.\n")
                exam_grade = int(input("Enter ex grade: "))
            total += ex_grade
            ex_grade_list.append(ex_grade)
        avg_ex = total/no_of_ex
        print("\nAverage ex grade:", avg_ex)
        
        #For quizes ........
        no_of_quizes = int(input("How many quizes were given? "))
        quiz_grade_list = []
        total = 0
        for i in range(0, no_of_quizes):
            quiz_grade = int(input("Enter quiz grade: "))
            while (quiz_grade not in range(0, 100)) :
                print("Invalid grade. Must be between 0 and 100.\n")
                quiz_grade = int(input("Enter quiz grade: "))
            total += quiz_grade
            quiz_grade_list.append(quiz_grade)
        avg_quiz = total/no_of_quizes
        print("\nAverage quiz grade:", avg_quiz)
        
        #For assignments ........
        no_of_asssignments = int(input("How many homework assignments were given? "))
        assignment_grade_list = []
        total = 0
        for i in range(0, no_of_asssignments):    
            assignment_grade = int(input("Enter homework grade: "))
            while (assignment_grade not in range(0, 100)):
                print("Invalid grade. Must be between 0 and 100.\n")
                assignment_grade = int(input("Enter homework grade: "))
            total += assignment_grade
            assignment_grade_list.append(assignment_grade)
        avg_assignment = total/no_of_asssignments
        print("\nAverage homework grade:", avg_assignment)
        
        avg_class = (avg_ex*0.4)+(avg_quiz*0.4)+(avg_assignment*0.2)
        print("\nFinal average for the class is:", round(avg_class, 1))
        print()
        
    else:
        print("Goodbye!")
        break
# Out:
# 1. Enter new student information
# 2. Exit
#
#
# Enter your choice here: 1
# You have chose to calculate the grade for student.
# How many exams were given? 3
# Enter exam grade: -10
# Invalid grade. Must be between 0 and 100.
#
# Enter exam grade: 90
# Enter exam grade: 88
# Enter exam grade: 82
#
# Average exam grade: 86.66666666666667
# How many quizes were given? 3
# Enter quiz grade: 88
# Enter quiz grade: 78
# Enter quiz grade: 89
#
# Average quiz grade: 85.0
# How many homework assignments were given? 3
# Enter homework grade: 78
# Enter homework grade: 99
# Enter homework grade: 80
#
# Average homework grade: 85.66666666666667
#
# Final average for the class is: 85.8
#
# 1. Enter new student information
# 2. Exit
#
#
# Enter your choice here: 1
# You have chose to calculate the grade for student.
# How many exams were given? 2
# Enter exam grade: 80
# Enter exam grade: 78
#
# Average exam grade: 79.0
# How many quizes were given? 3
# Enter quiz grade: 78
# ...
