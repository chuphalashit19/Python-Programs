# %%
class Product:
    # Part 1
    def __init__(self, name, quantity, price, weight, barcode):
        # TODO: constructor
        self.name =  name
        self.quantity = quantity
        self.price = price
        self.weight = weight
        self.barcode = barcode
        
    def __repr__(self):
        # Do not modify
        return "{} x {}: {:.2f}kg, ${:.2f} code:{}".format(self.quantity, self.name, self.weight/1000, self.price/100, self.barcode)
  
    def is_valid(self):
        return self.name != 'INVALID'

    def set_invalid(self):
        self.name = 'INVALID'
        self.price = -1
        self.quantity = -1
        self.weight = -1
        self.barcode = '0'

    # TODO - Getter and Setter methods
    def get_name(self):
        # TODO
        pass

    def set_name(self, name):
        # TODO
        pass

    def get_quantity(self):
        # TODO
        pass

    def set_quantity(self, quantity):
        # TODO
        pass

    def get_price(self):
        # TODO
        pass

    def set_price(self, price):
        # TODO
        pass

    def get_weight(self):
        # TODO
        pass

    def set_weight(self, weight):
        # TODO
        pass

    def get_barcode(self):
        # TODO
        pass

    def set_barcode(self, barcode):
        # TODO
        pass

    # Part 2

    def parse_inventory(filename):
        """
        - Read the inventory file and check for Errors
        -- raise a NameError if the provided filename
        cannot be opened
        -- raise a TypeError if the file does not
        conform to the format
        - Parse products in the inventory file into Product objects
        - Return the list of Product objects, in the order they appear in the file
        """
        # TODO
        pass

    # Part 3

    def dollars_per_100g(self):
        """
        Calculate how much 100g of the product costs in dollars.
        Return the floating point value result
          
        Example
        -------
        Apple,6,1000,700g: $10 buys 700g of Apples, so
        it costs $1.42857142857... per 100g -> return 1.42857142857...
        """
        # TODO
        pass

    def heaviest_product(products):
        """
        Find the heaviest product.

        If there are two or more products with the same heaviest weight,
        return the first product as it appears in the list.

        If the products list is empty, return None

        Parameters
        ----------
        products: A list of Product objects

        Returns
        -------
        Product object with highest weight
        """
        # TODO
        pass

    def cheapest_product(products):
        """
        Find the product with the cheapest price.

        If there are two or more products with the same cheapest price,
        return the first product as it appears in the list.

        If the products list is empty, return None

        Parameters
        ----------
        products: A list of Product objects

        Returns
        -------
        Product object with lowest price
        """
        # TODO
        pass
  
    def create_file(products, filename):
        """
        Write a product file using the given arguments,
        and using the file format specified in the example.

        If the products list is empty, write an empty file

        Parameters
        ----------
        products: A list of Product objects
        filename: The name of the file to write to
        """
        pass
    
if __name__ == "__main__":
    Product("Apple", 6, 1000, 700, "101010101010101010")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-94a5c58a3836> in <module>
#     150 if __name__ == "__main__":
#     151     Product("Apple", 6, 1000, 700, "101010101010101010")
# --> 152     is_valid(Product)
#
# NameError: name 'is_valid' is not defined
